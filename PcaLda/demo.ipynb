# %%
import numpy as np
import json
import h5py
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA, LatentDirichletAllocation
from scipy.fftpack import fft

# %%
AES_Sbox = np.array([
    
])

# %%
with open('../utils.json', 'r') as f:    
    json_data = json.load(f)
    file_path = json_data['data']['path']

with h5py.File(file_path, 'r') as h5f:
    traces = h5f['traces'][()]
    plaintexts = h5f['plaintext'][()]
    ciphertexts = h5f['ciphertext'][()]
    keys = h5f['keys'][()]

# %%
# 锚点
traces.shape
# Out:
# (2000, 15000)

# %% [markdown]
# * PCA

# %%
pca = PCA(700)
# fft_traces = abs(fft(traces))
pca.fit(traces)
pca_data = pca.transform(traces)

pca_data.shape
# Out:
# (2000, 700)

# %%
plt.figure(figsize=(15, 7))
sns.set_theme()
plt.plot(pca_data[0])
plt.show()

# %% [markdown]
# * LDA

# %%
# 监督学习算法, 如果要predict的话需要 拿每条能量迹label的HW作为标签 
# 这里没做预测 ^^
def get_hw(mid_val):
    return bin(mid_val).count('1')

def cal_hw_midval(plaintexts, keys, position):
    mid_val = np.zeros(shape=(plaintexts.shape[0], 1), dtype=int)
    for index, plaintext in enumerate(plaintexts):
        mid_val[index] = get_hw(AES_Sbox[keys[index][position] ^ plaintext[position]])
    return mid_val
label = cal_hw_midval(plaintexts, keys, 2)

# %%
lda = LatentDirichletAllocation(n_components=500)    # 这里有三种求解器
lda_data = lda.fit_transform(abs(traces[:1000]))   # TODO: 晚上跑
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 lda = LatentDirichletAllocation(n_components=500)    # 这里有三种求解器
# ----> 2 lda_data = lda.fit_transform(abs(traces))
#
# File ~/miniconda3/envs/mlp_test/lib/python3.8/site-packages/sklearn/base.py:852, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     848 # non-optimized default implementation; override when a better
#     849 # method is possible for a given clustering algorithm
#     850 if y is None:
#     851     # fit method of arity 1 (unsupervised transformation)
# --> 852     return self.fit(X, **fit_params).transform(X)
#     853 else:
#     854     # fit method of arity 2 (supervised transformation)
#     855     return self.fit(X, y, **fit_params).transform(X)
#
# ...

# %%
plt.figure(figsize=(15, 7))
sns.set_theme()
plt.plot(lda_data[0])
plt.show()
